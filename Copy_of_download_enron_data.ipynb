# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashlay01/Ash21212022/blob/main/Copy_of_download_enron_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Downloading Enron Email Data
#
#
#
# ### Full/Complete Dataset
#
# The following code-cell will download the complete Enron email database to the Colab instance.  It will take about 1-2 mins to download.

# %%
# !wget -O enron.db https://curtin-my.sharepoint.com/:u:/g/personal/211934g_curtin_edu_au/EaYagsqa2r1Bi5wtHbswGFwBH2kd2uTnz6rlka7GI36GUQ?download=1
# Out:
# --2023-05-16 11:46:34--  https://curtin-my.sharepoint.com/:u:/g/personal/211934g_curtin_edu_au/EaYagsqa2r1Bi5wtHbswGFwBH2kd2uTnz6rlka7GI36GUQ?download=1
# Resolving curtin-my.sharepoint.com (curtin-my.sharepoint.com)... 13.107.136.8, 13.107.138.8, 2620:1ec:8f8::8, ...
# Connecting to curtin-my.sharepoint.com (curtin-my.sharepoint.com)|13.107.136.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/211934g_curtin_edu_au/Documents/Teaching/ISYS2001/ISYS2001-Assignment-2-Data/enron_sqlite3.db?ga=1 [following]
# --2023-05-16 11:46:35--  https://curtin-my.sharepoint.com/personal/211934g_curtin_edu_au/Documents/Teaching/ISYS2001/ISYS2001-Assignment-2-Data/enron_sqlite3.db?ga=1
# Reusing existing connection to curtin-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 853819392 (814M) [application/octet-stream]
# Saving to: ‘enron.db’
#
# enron.db            100%[===================>] 814.27M  25.6MB/s    in 36s
#
# 2023-05-16 11:47:12 (22.3 MB/s) - ‘enron.db’ saved [853819392/853819392]

# %%
import sqlite3

# %%
conn = sqlite3.connect("enron.db")

# %%
cur = conn.cursor()

# %%
#check schema of database
sql = """
SELECT name
FROM sqlite_master
WHERE type = "table";
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [('employeelist',), ('message',), ('recipientinfo',), ('referenceinfo',)]

# %%
#check schema of table employeelist using PRAGMA 
sql = """
PRAGMA table_info('employeelist');
"""

cur.execute(sql)
cur.fetchall()
# Out:
# [(0, 'eid', 'INTEGER', 1, None, 1),
#  (1, 'firstName', 'VARCHAR(31)', 1, "''", 0),
#  (2, 'lastName', 'VARCHAR(31)', 1, "''", 0),
#  (3, 'Email_id', 'VARCHAR(31)', 1, "''", 0),
#  (4, 'Email2', 'VARCHAR(31)', 0, None, 0),
#  (5, 'Email3', 'VARCHAR(31)', 0, None, 0),
#  (6, 'EMail4', 'VARCHAR(31)', 0, None, 0),
#  (7, 'folder', 'VARCHAR(31)', 1, "''", 0),
#  (8, 'status', 'VARCHAR(50)', 0, None, 0)]

# %%
#check schema of table message using PRAGMA 
sql = """
PRAGMA table_info('message');
"""

cur.execute(sql)
cur.fetchall()
# Out:
# [(0, 'mid', 'INTEGER', 1, "'0'", 1),
#  (1, 'sender', 'VARCHAR(127)', 1, "''", 0),
#  (2, 'date', 'DATETIME', 0, None, 0),
#  (3, 'message_id', 'VARCHAR(127)', 0, None, 0),
#  (4, 'subject', 'TEXT', 0, None, 0),
#  (5, 'body', 'TEXT', 0, None, 0),
#  (6, 'folder', 'VARCHAR(127)', 1, "''", 0)]

# %%
#check schema of table recipientinfo using PRAGMA 
sql = """
PRAGMA table_info('recipientinfo');
"""

cur.execute(sql)
cur.fetchall()
# Out:
# [(0, 'rid', 'INTEGER', 1, "'0'", 1),
#  (1, 'mid', 'INTEGER', 1, "'0'", 0),
#  (2, 'rtype', 'TEXT', 0, None, 0),
#  (3, 'rvalue', 'VARCHAR(127)', 0, None, 0),
#  (4, 'dater', 'DATETIME', 0, None, 0)]

# %%
#check schema of table using referenceinfo PRAGMA 
sql = """
PRAGMA table_info('referenceinfo');
"""

cur.execute(sql)
cur.fetchall()
# Out:
# [(0, 'rfid', 'INTEGER', 1, "'0'", 1),
#  (1, 'mid', 'INTEGER', 1, "'0'", 0),
#  (2, 'reference', 'TEXT', 0, None, 0)]

# %%
#using pandas library to read database
import pandas as pd

sql='''
SELECT * from employeelist;
'''
# Load the data into a DataFrame
employeelist_df = pd.read_sql_query(sql, conn)
employeelist_df
# Out:
#     eid firstName     lastName                     Email_id  \
# 0     1    Robert       Badeer      robert.badeer@enron.com
# 1     2     Kevin        Hyatt        kevin.hyatt@enron.com
# 2     3     Tracy     Geaccone     tracy.geaccone@enron.com
# 3     4       Teb        Lokey          teb.lokey@enron.com
# 4     5   Richard         Ring       richard.ring@enron.com
# ..  ...       ...          ...                          ...
# 61   62     Peter       Keavey       peter.keavey@enron.com
# 62   63     Scott  Hendrickson  scott.hendrickson@enron.com
# 63   64       Tom      Donohoe        tom.donohoe@enron.com
# 64   65      Mark     Haedicke        e..haedicke@enron.com
# 65   66   Stanley       Horton     stanley.horton@enron.com
#
#                            Email2                     Email3  \
# 0               rbadeer@enron.com
# 1           kevin_hyatt@enron.com           khyatt@enron.com
# 2        tracy_geaconne@enron.com
# 3             teb_lokey@enron.com           tlokey@enron.com
# 4
# ..                            ...                        ...
# 61            f..keavey@enron.com          pkeavey@enron.com
# 62  scott . hendrikcson@enron.com
# 63
# 64        mark.haedicke@enron.com  mark.e.haedicke@enron.com
# 65       stanley_horton@enron.com
#
#                       EMail4         folder             status
# 0                                  badeer-r           Director
# 1                                   hyatt-k           Director
# 2                                geaccone-t           Employee
# 3                                   lokey-t            Manager
# 4                                    ring-r           Employee
# ..                       ...            ...                ...
# 61  peter.f.keavey@enron.com       keavey-p           Employee
# 62                            hendrickson-s                N/A
# 63                                donohoe-t           Employee
# 64                               haedicke-m  Managing Director
# 65                                 horton-s          President
#
# [66 rows x 9 columns]

# %%
#using pandas library to read database
import pandas as pd

sql='''
SELECT * from message;
'''
# Load the data into a DataFrame
message_df = pd.read_sql_query(sql, conn)
Message_df
# Out:
#      mid                     sender                 date  \
# 0     52    press.release@enron.com  2000-01-21 04:51:00
# 1     53  office.chairman@enron.com  2000-01-24 01:37:00
# 2     54  office.chairman@enron.com  2000-01-24 02:06:00
# 3     55    press.release@enron.com  2000-02-02 10:21:00
# 4     56  office.chairman@enron.com  2000-02-07 22:16:00
# ..   ...                        ...                  ...
# 129  181    carla.hoffman@enron.com  2000-08-11 03:12:00
# 130  182    carla.hoffman@enron.com  2000-08-14 07:08:00
# 131  183    carla.hoffman@enron.com  2000-08-15 01:11:00
# 132  184    carla.hoffman@enron.com  2000-08-16 01:30:00
# 133  185    carla.hoffman@enron.com  2000-08-16 02:09:00
#
#                                         message_id  \
# 0    <12435833.1075863606729.JavaMail.evans@thyme>
# 1    <29664079.1075863606676.JavaMail.evans@thyme>
# 2    <15300605.1075863606629.JavaMail.evans@thyme>
# 3    <10522232.1075863606538.JavaMail.evans@thyme>
# 4    <16056123.1075863606515.JavaMail.evans@thyme>
# ..                                             ...
# 129  <12270227.1075863603271.JavaMail.evans@thyme>
# 130  <28653863.1075863603246.JavaMail.evans@thyme>
# 131  <30880886.1075863603219.JavaMail.evans@thyme>
# 132  <22985036.1075863603193.JavaMail.evans@thyme>
# 133  <13577266.1075863603169.JavaMail.evans@thyme>
#
#                                                subject  \
# 0    ENRON HOSTS ANNUAL ANALYST CONFERENCE PROVIDES...
# 1                      Over $50 -- You made it happen!
# 2                      Over $50 -- You made it happen!
# 3    ROAD-SHOW.COM Q4i.COM CHOOSE ENRON TO DELIVER ...
# 4                         Fortune Most Admired Ranking
# ..                                                 ...
# 129  DJ Rising Electricity Prices Could Be Wild Car...
# 130  DJ POWER CUTS: Blackouts Lead Firms To Examine...
# 131  DJ Calif Pwr Producers Urge FERC Reject Price ...
# 132  DJ Calif ISO Exceeded $250 Cap In Off-system B...
# 133  DJ Calif Generators: `We Welcome Probe Into Po...
#
#                                                   body  \
# 0    HOUSTON - Enron Corp. hosted its annual equity...
# 1    On Wall Street, people are talking about Enron...
# 2    On Wall Street, people are talking about Enron...
# 3    HOUSTON =01) Enron Broadband Services (EBS), a...
# 4    Congratulations!  For an unprecedented five ye...
# ..                                                 ...
# 129  ---------------------- Forwarded by Carla Hoff...
# 130  ---------------------- Forwarded by Carla Hoff...
# 131  ---------------------- Forwarded by Carla Hoff...
# 132  ---------------------- Forwarded by Carla Hoff...
# 133  ---------------------- Forwarded by Carla Hoff...
#
#                                                folder
# 0    Robert_Badeer_Aug2000Notes FoldersPress releases
# 1    Robert_Badeer_Aug2000Notes FoldersPress releases
# 2    Robert_Badeer_Aug2000Notes FoldersPress releases
# 3    Robert_Badeer_Aug2000Notes FoldersPress releases
# 4    Robert_Badeer_Aug2000Notes FoldersPress releases
# ..                                                ...
# 129     Robert_Badeer_Aug2000Notes FoldersDj articles
# 130     Robert_Badeer_Aug2000Notes FoldersDj articles
# 131     Robert_Badeer_Aug2000Notes FoldersDj articles
# 132     Robert_Badeer_Aug2000Notes FoldersDj articles
# 133     Robert_Badeer_Aug2000Notes FoldersDj articles
#
# [134 rows x 7 columns]

# %%
#using pandas library to read database
import pandas as pd

sql='''
SELECT * from recipientinfo;
'''
# Load the data into a DataFrame
recipientinfo_df = pd.read_sql_query(sql, conn)
recipientinfo_df
# Out:
#     rid  mid rtype                             rvalue dater
# 0    67   52    TO            all.worldwide@enron.com  None
# 1    68   53    TO             all.downtown@enron.com  None
# 2    69   54    TO      all.enron-worldwide@enron.com  None
# 3    70   55    TO            all.worldwide@enron.com  None
# 4    71   56    TO  all_enron_north.america@enron.com  None
# ..  ...  ...   ...                                ...   ...
# 90  157   67    TO               tim.belden@enron.com  None
# 91  158   67    TO            robert.badeer@enron.com  None
# 92  159   67    TO              jake.thomas@enron.com  None
# 93  160   67    TO         michael.mcdonald@enron.com  None
# 94  161   67    TO               greg.wolfe@enron.com  None
#
# [95 rows x 5 columns]

# %%
#using pandas library to read database
import pandas as pd

sql='''
SELECT * from referenceinfo;
'''
# Load the data into a DataFrame
referenceinfo_df = pd.read_sql_query(sql, conn)
referenceinfo_df
# Out:
#     rfid   mid                                          reference
# 0      2    79  > From: Le Vine, Debi> Sent: Thursday, August ...
# 1      3    99  > From: Golden, Mark> Sent: Thursday, August 2...
# 2      8   533  From: Sole, JeanneSent: Friday, August 18, 200...
# 3     13   842  From: \tGrigsby, Mike  Sent:\tThursday, March ...
# 4     14   845  From: Monaco, John [EM] [mailto:john.monaco@ci...
# ..   ...   ...                                                ...
# 89    99  1027  From: Hyatt, Kevin Sent: Thursday, August 09, ...
# 90   100  1032  From: \tHyatt, Kevin  Sent:\tFriday, August 03...
# 91   101  1038  From: \tHyatt, Kevin  Sent:\tFriday, February ...
# 92   102  1042  From: \tHyatt, Kevin  Sent:\tWednesday, Septem...
# 93   103  1045  From: \tGadd, Eric  Sent:\tWednesday, August 1...
#
# [94 rows x 3 columns]

# %%
#cleaning null values from dataframe
clean = employeelist_df.dropna()
clean
# Out:
#     eid firstName     lastName                     Email_id  \
# 0     1    Robert       Badeer      robert.badeer@enron.com
# 1     2     Kevin        Hyatt        kevin.hyatt@enron.com
# 2     3     Tracy     Geaccone     tracy.geaccone@enron.com
# 3     4       Teb        Lokey          teb.lokey@enron.com
# 4     5   Richard         Ring       richard.ring@enron.com
# ..  ...       ...          ...                          ...
# 61   62     Peter       Keavey       peter.keavey@enron.com
# 62   63     Scott  Hendrickson  scott.hendrickson@enron.com
# 63   64       Tom      Donohoe        tom.donohoe@enron.com
# 64   65      Mark     Haedicke        e..haedicke@enron.com
# 65   66   Stanley       Horton     stanley.horton@enron.com
#
#                            Email2                     Email3  \
# 0               rbadeer@enron.com
# 1           kevin_hyatt@enron.com           khyatt@enron.com
# 2        tracy_geaconne@enron.com
# 3             teb_lokey@enron.com           tlokey@enron.com
# 4
# ..                            ...                        ...
# 61            f..keavey@enron.com          pkeavey@enron.com
# 62  scott . hendrikcson@enron.com
# 63
# 64        mark.haedicke@enron.com  mark.e.haedicke@enron.com
# 65       stanley_horton@enron.com
#
#                       EMail4         folder             status
# 0                                  badeer-r           Director
# 1                                   hyatt-k           Director
# 2                                geaccone-t           Employee
# 3                                   lokey-t            Manager
# 4                                    ring-r           Employee
# ..                       ...            ...                ...
# 61  peter.f.keavey@enron.com       keavey-p           Employee
# 62                            hendrickson-s                N/A
# 63                                donohoe-t           Employee
# 64                               haedicke-m  Managing Director
# 65                                 horton-s          President
#
# [65 rows x 9 columns]

# %%
#cleaning null values from dataframe
clean = Message_df.dropna()
clean
# Out:
#      mid                     sender                 date  \
# 0     52    press.release@enron.com  2000-01-21 04:51:00
# 1     53  office.chairman@enron.com  2000-01-24 01:37:00
# 2     54  office.chairman@enron.com  2000-01-24 02:06:00
# 3     55    press.release@enron.com  2000-02-02 10:21:00
# 4     56  office.chairman@enron.com  2000-02-07 22:16:00
# ..   ...                        ...                  ...
# 129  181    carla.hoffman@enron.com  2000-08-11 03:12:00
# 130  182    carla.hoffman@enron.com  2000-08-14 07:08:00
# 131  183    carla.hoffman@enron.com  2000-08-15 01:11:00
# 132  184    carla.hoffman@enron.com  2000-08-16 01:30:00
# 133  185    carla.hoffman@enron.com  2000-08-16 02:09:00
#
#                                         message_id  \
# 0    <12435833.1075863606729.JavaMail.evans@thyme>
# 1    <29664079.1075863606676.JavaMail.evans@thyme>
# 2    <15300605.1075863606629.JavaMail.evans@thyme>
# 3    <10522232.1075863606538.JavaMail.evans@thyme>
# 4    <16056123.1075863606515.JavaMail.evans@thyme>
# ..                                             ...
# 129  <12270227.1075863603271.JavaMail.evans@thyme>
# 130  <28653863.1075863603246.JavaMail.evans@thyme>
# 131  <30880886.1075863603219.JavaMail.evans@thyme>
# 132  <22985036.1075863603193.JavaMail.evans@thyme>
# 133  <13577266.1075863603169.JavaMail.evans@thyme>
#
#                                                subject  \
# 0    ENRON HOSTS ANNUAL ANALYST CONFERENCE PROVIDES...
# 1                      Over $50 -- You made it happen!
# 2                      Over $50 -- You made it happen!
# 3    ROAD-SHOW.COM Q4i.COM CHOOSE ENRON TO DELIVER ...
# 4                         Fortune Most Admired Ranking
# ..                                                 ...
# 129  DJ Rising Electricity Prices Could Be Wild Car...
# 130  DJ POWER CUTS: Blackouts Lead Firms To Examine...
# 131  DJ Calif Pwr Producers Urge FERC Reject Price ...
# 132  DJ Calif ISO Exceeded $250 Cap In Off-system B...
# 133  DJ Calif Generators: `We Welcome Probe Into Po...
#
#                                                   body  \
# 0    HOUSTON - Enron Corp. hosted its annual equity...
# 1    On Wall Street, people are talking about Enron...
# 2    On Wall Street, people are talking about Enron...
# 3    HOUSTON =01) Enron Broadband Services (EBS), a...
# 4    Congratulations!  For an unprecedented five ye...
# ..                                                 ...
# 129  ---------------------- Forwarded by Carla Hoff...
# 130  ---------------------- Forwarded by Carla Hoff...
# 131  ---------------------- Forwarded by Carla Hoff...
# 132  ---------------------- Forwarded by Carla Hoff...
# 133  ---------------------- Forwarded by Carla Hoff...
#
#                                                folder
# 0    Robert_Badeer_Aug2000Notes FoldersPress releases
# 1    Robert_Badeer_Aug2000Notes FoldersPress releases
# 2    Robert_Badeer_Aug2000Notes FoldersPress releases
# 3    Robert_Badeer_Aug2000Notes FoldersPress releases
# 4    Robert_Badeer_Aug2000Notes FoldersPress releases
# ..                                                ...
# 129     Robert_Badeer_Aug2000Notes FoldersDj articles
# 130     Robert_Badeer_Aug2000Notes FoldersDj articles
# 131     Robert_Badeer_Aug2000Notes FoldersDj articles
# 132     Robert_Badeer_Aug2000Notes FoldersDj articles
# 133     Robert_Badeer_Aug2000Notes FoldersDj articles
#
# [134 rows x 7 columns]

# %%
#cleaning null values from dataframe

recipientinfo_df.info()
recipientinfo_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rid     95 non-null     int64
#  1   mid     95 non-null     int64
#  2   rtype   95 non-null     object
#  3   rvalue  95 non-null     object
#  4   dater   0 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 3.8+ KB
#               rid        mid
# count   95.000000  95.000000
# mean   114.000000  62.757895
# std     27.568098   3.231217
# min     67.000000  52.000000
# 25%     90.500000  61.000000
# 50%    114.000000  63.000000
# 75%    137.500000  66.000000
# max    161.000000  67.000000

# %%
#cleaning null values from dataframe
clean =  referenceinfo_df.dropna()
clean
# Out:
#     rfid   mid                                          reference
# 0      2    79  > From: Le Vine, Debi> Sent: Thursday, August ...
# 1      3    99  > From: Golden, Mark> Sent: Thursday, August 2...
# 2      8   533  From: Sole, JeanneSent: Friday, August 18, 200...
# 3     13   842  From: \tGrigsby, Mike  Sent:\tThursday, March ...
# 4     14   845  From: Monaco, John [EM] [mailto:john.monaco@ci...
# ..   ...   ...                                                ...
# 89    99  1027  From: Hyatt, Kevin Sent: Thursday, August 09, ...
# 90   100  1032  From: \tHyatt, Kevin  Sent:\tFriday, August 03...
# 91   101  1038  From: \tHyatt, Kevin  Sent:\tFriday, February ...
# 92   102  1042  From: \tHyatt, Kevin  Sent:\tWednesday, Septem...
# 93   103  1045  From: \tGadd, Eric  Sent:\tWednesday, August 1...
#
# [94 rows x 3 columns]
